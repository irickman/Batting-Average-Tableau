# %%
import pandas as pd
from pybaseball import statcast,playerid_reverse_lookup
from pybaseball import schedule_and_record
from datetime import datetime
import time
pd.options.display.max_rows=100
pd.options.display.max_columns=100

# %%
prev_data=statcast("2018-7-5","2018-7-13")
# Out:
# This is a large query, it may take a moment to complete
# Completed sub-query from 2018-07-05 to 2018-07-10
# Completed sub-query from 2018-07-11 to 2018-7-13

# %%
latest=prev_data[prev_data.events.notnull()]
latest.to_csv("abs_7-13.csv",index=False)

# %%
df1=pd.read_csv("abs_5-11.csv")
df2=pd.read_csv("abs_6-24.csv")
df3=pd.read_csv("abs_7-4.csv")
df4=pd.read_csv("abs_7-13.csv")

# %%
df1.shape,df2.shape,df3.shape,df4.shape
# Out:
# ((38831, 89), (40000, 89), (10350, 90), (8183, 90))

# %%
df=pd.concat([df1,df2,df3,df4],axis=0).reset_index(drop=True)

# %%
players_ids.head()
# Out:
#   name_last name_first  key_mlbam key_retro  key_bbref  key_fangraphs  \
# 0     abreu       jose     547989  abrej003  abreujo02          15676
# 1     acuna     ronald     660670       NaN  acunaro01          18401
# 2    adames      willy     642715       NaN  adamewi01          15986
# 3     adams       lane     572669  adaml001  adamsla01          10767
# 4     adams       matt     571431  adamm002  adamsma01           9393
#
#    mlb_played_first  mlb_played_last
# 0            2014.0           2018.0
# 1            2018.0           2018.0
# 2            2018.0           2018.0
# 3            2014.0           2018.0
# 4            2012.0           2018.0

# %%
players_ids=playerid_reverse_lookup(df.batter.unique())
id_df=players_ids[['name_last','name_first','key_mlbam']]
# Out:
# Gathering player lookup table. This may take a moment.

# %%
df2=df.merge(id_df, how = 'left',left_on='batter',right_on='key_mlbam')
df3=df2.drop(['key_mlbam'],axis=1)

# %%
df3.to_pickle("lastabs.pkl")

# %%
df3['']
# Out:
#    index pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0    271         FT  2018-07-12           95.2        -1.6777         6.4294
# 1    291         FF  2018-07-12           94.7        -1.6669         6.4115
# 2    334         FF  2018-07-12           94.8        -1.4456         6.4651
# 3    364         SI  2018-07-12           97.7        -1.4858         6.0982
# 4    404         SL  2018-07-12           89.5        -1.5422         6.1567
#
#       player_name    batter   pitcher                     events  \
# 0     Ryan Madson  642708.0  425492.0  grounded_into_double_play
# 1     Ryan Madson  408314.0  425492.0                  force_out
# 2     Ryan Madson  608700.0  425492.0                     single
# 3  Jeurys Familia  448602.0  544727.0                  strikeout
# 4  Jeurys Familia  547180.0  544727.0                  strikeout
#
#             description  spin_dir  spin_rate_deprecated  \
# ...

# %%
df.player_name.nunique()
# Out:
# 1069

# %%
df.events.value_counts()
# Out:
# field_out                       42389
# strikeout                       23682
# single                          15050
# double                           4804
# home_run                         3187
# force_out                        2154
# grounded_into_double_play        2035
# walk                             1451
# sac_fly                           684
# sac_bunt                          467
# triple                            467
# double_play                       257
# hit_by_pitch                      186
# fielders_choice_out               179
# field_error                       159
# strikeout_double_play             100
# fielders_choice                    59
# caught_stealing_2b                 27
# sac_fly_double_play                 6
# pickoff_caught_stealing_2b          5
# catcher_interf                      3
# other_out                           3
# pickoff_caught_stealing_3b          2
# pickoff_1b                          2
# pickoff_caught_stealing_home        1
# ...

# %%
df.events.isnull().sum()
# Out:
# 0

# %%
df['hit']=df.events.apply(lambda x: 1 if x in ["single",'double','home_run','triple'] else 0)
df['ab']=df.events.apply(lambda x: 0 if x in ["sac_fly",'sac_bunt','sac_fly_double_play','sac_bunt_double_play'] else 1)

# %%
df['date']=pd.to_datetime(df['game_date'],infer_datetime_format=True)
sorted(df.date.unique())
# Out:
# [numpy.datetime64('2018-03-29T00:00:00.000000000'),
#  numpy.datetime64('2018-03-30T00:00:00.000000000'),
#  numpy.datetime64('2018-03-31T00:00:00.000000000'),
#  numpy.datetime64('2018-04-01T00:00:00.000000000'),
#  numpy.datetime64('2018-04-02T00:00:00.000000000'),
#  numpy.datetime64('2018-04-03T00:00:00.000000000'),
#  numpy.datetime64('2018-04-04T00:00:00.000000000'),
#  numpy.datetime64('2018-04-05T00:00:00.000000000'),
#  numpy.datetime64('2018-04-06T00:00:00.000000000'),
#  numpy.datetime64('2018-04-07T00:00:00.000000000'),
#  numpy.datetime64('2018-04-08T00:00:00.000000000'),
#  numpy.datetime64('2018-04-09T00:00:00.000000000'),
#  numpy.datetime64('2018-04-10T00:00:00.000000000'),
#  numpy.datetime64('2018-04-11T00:00:00.000000000'),
#  numpy.datetime64('2018-04-12T00:00:00.000000000'),
#  numpy.datetime64('2018-04-13T00:00:00.000000000'),
#  numpy.datetime64('2018-04-14T00:00:00.000000000'),
#  numpy.datetime64('2018-04-15T00:00:00.000000000'),
# ...

# %%
df['htd']=df.sort_values(['date','inning'],ascending=True).groupby(['player_name']).hit.cumsum()
df['abtd']=df.sort_values(['date','inning'],ascending=True).groupby(['player_name']).ab.cumsum()
df['avg']=df.htd/df.abtd

# %%
df[['player_name','date','inning','hit','ab','htd','abtd','avg']].sort_values(['player_name','date','inning'],ascending=True).head(100)
# Out:
#       player_name       date  inning  hit  ab  htd  abtd       avg
# 34342   A.J. Cole 2018-04-03     2.0    1   1    1     1  1.000000
# 34191   A.J. Cole 2018-04-03     3.0    0   1    1     2  0.500000
# 27480   A.J. Cole 2018-04-11     3.0    0   0    1     2  0.500000
# 27261   A.J. Cole 2018-04-11     5.0    0   1    1     3  0.333333
# 81077   A.J. Cole 2018-07-03     5.0    0   1    1     4  0.250000
# 81078   A.J. Cole 2018-07-03     5.0    1   1    2     5  0.400000
# 81079   A.J. Cole 2018-07-03     5.0    0   1    2     6  0.333333
# 81070   A.J. Cole 2018-07-03     6.0    0   1    2     7  0.285714
# 81071   A.J. Cole 2018-07-03     6.0    0   1    2     8  0.250000
# 81072   A.J. Cole 2018-07-03     6.0    0   1    2     9  0.222222
# 93153   A.J. Cole 2018-07-09     7.0    0   1    2    10  0.200000
# 93154   A.J. Cole 2018-07-09     7.0    1   1    3    11  0.272727
# 93155   A.J. Cole 2018-07-09     7.0    0   1    3    12  0.250000
# ...

# %%
df['player_team']=df.apply(lambda x: x.home_team if x.inning_topbot=="Bot" else x.away_team,axis=1)

# %%
teams=df.player_team.unique()
fixers={"WSH":"WSN","CWS":"CHW"}
teams_fixed=[x if x not in fixers.keys() else fixers[x] for x in teams]

# %%
team_schedule={}
missed=[]
for t in teams_fixed:
    try:
        d=schedule_and_record(2018,t)
        d['fix_date']=d.Date.str.replace("\(\d\)","").str.strip() + " 2018"
        d['game_date']=pd.to_datetime(d.fix_date.apply(lambda x: datetime.strptime(x,"%A, %b %d %Y")).apply(lambda x: x.strftime("%Y-%m-%d")),infer_datetime_format=True)
        d['place']=d.Home_Away.apply(lambda x: "Home" if x=="Home" else "Away")
        d2=d[d.game_date>=datetime.today()][['Tm','place',"Opp","game_date"]]
        team_schedule[t]=d2
    except ValueError:
        print(t)
        missed.append(t)

# %%
df.drop_duplicates(['player_name','player_team']).player_name.value_counts()
print("the only players with the same names are players who have been traded")
# Out:
# the only players with the same names are players who have been traded

# %%
trim_df.dtypes
# Out:
# player_name    object
# player_team    object
# game_date      object
# ab              int64
# hit             int64
# dtype: object

# %%
## realistically, I only actually need the hit, game date, team and players
trim_df=df[['player_name','player_team','game_date','ab','hit']]
trim_df.head()
# Out:
#         player_name player_team   game_date  ab  hit
# 0   Carlos Gonzalez         COL  2018-05-11   1    0
# 1     Nolan Arenado         COL  2018-05-11   1    0
# 2  Charlie Blackmon         COL  2018-05-11   1    0
# 3     Jesus Aguilar         MIL  2018-05-11   1    0
# 4       Travis Shaw         MIL  2018-05-11   1    1

# %%
def player_df(player, d=trim_df):
    temp = d[d.player_name==player]
    temp=temp.sort_values(['game_date']).reset_index(drop=True)
    tm=temp.loc[len(temp)-1,'player_team']
    if tm in fixers.keys():
        sched=team_schedule[fixers[tm]]
    else:
        sched=team_schedule[tm]
    tdf= pd.concat([temp,sched])
    tdf.ab.fillna(0,inplace=True)
    tdf.hit.fillna(0,inplace=True)
    tdf.player_name.fillna(player,inplace=True)
    tdf.player_team.fillna(tm,inplace=True)
    return tdf

# %%
def timer(starter):
    t=time.time()-starter
    minutes=(t-(t%60))/60
    seconds=t%60
    print("it took {:.0f} minutes and {:.2f} seconds".format(minutes,seconds))

# %%
start=time.time()
master_df=player_df(trim_df.player_name.unique()[0])
for p in trim_df.player_name.unique()[1:]:
    got=player_df(p)
    master_df=pd.concat([master_df,got])
print(master_df.shape)
timer(start)
# Out:
# (169869, 8)
# it took 0 minutes and 41.10 seconds

# %%
master_df.to_csv("master_test.csv",index=False)

# %%
# %%timeit
master_df=player_df(trim_df.player_name.unique()[0])
for p in trim_df.player_name.unique()[1:5]:
    got=player_df(p)
    master_df=master_df.append(got)
# Out:
# 1 loop, best of 3: 2.08 s per loop

# %%
master_df.shape
# Out:
# (445905, 97)

# %%
got.shape
# Out:
# (89181, 97)

# %%
## in case i lose the schedules
for k in team_schedule.keys():
    team_schedule[k].to_pickle("Schedules_7-5-18/{}.pkl".format(k))

# %%
df.player_name.nunique()
# Out:
# 1028

# %%
for r in missed:
    try:
        d=schedule_and_record(2018,r)
        d['fix_date']=d.Date + " 2018"
        d['game_date']=pd.to_datetime(d.fix_date.apply(lambda x: datetime.strptime(x,"%A, %b %d %Y")).apply(lambda x: x.strftime("%Y-%m-%d")),infer_datetime_format=True)
        d['place']=d.Home_Away.apply(lambda x: "Home" if x=="Home" else "Away")
        d2=d[d.game_date>=datetime.today()][['Tm','place',"Opp","game_date"]]
        team_schedule[r]=d2
    except ValueError:
        print(r)
# Out:
# CWS
# CLE
# TOR
# CHC
# KC
# SF
# PIT
# LAD
# MIN
# NYY
# CIN
# OAK
# ATL
# NYM
# TB
# BAL
# WSH
# SEA
# DET

# %%
missing_schedules={}
for r in missed:
    try:
        d=schedule_and_record(2018,r)
        missing_schedules[r]=d
    except ValueError:
        print(r)
# Out:
# CWS
# WSH

# %%
for r in missing_schedules.keys():
    d=missing_schedules[r]
    d['fix_date']=d.Date.str.replace("\(\d\)","").str.strip() + " 2018"
    try:
        d['game_date']=pd.to_datetime(d.fix_date.apply(lambda x: datetime.strptime(x,"%A, %b %d %Y")).apply(lambda x: x.strftime("%Y-%m-%d")),infer_datetime_format=True)
    except ValueError:
        print("didn't work for {}".format(r))
# Out:
# didn't work for KC
# didn't work for DET
# didn't work for CHC
# didn't work for MIN
# didn't work for TOR
# didn't work for CLE
# didn't work for ATL
# didn't work for TB
# didn't work for OAK
# didn't work for CIN
# didn't work for LAD
# didn't work for NYY
# didn't work for SEA
# didn't work for NYM
# didn't work for BAL
# didn't work for PIT
# didn't work for SF

# %%
df.to_csv("all_abs_edit.csv")

# %%
## statcast test
# %timeit
data=statcast()
# Out:
# ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-63bb5460ed4c> in <module>()
#       1 ## statcast test
#       2 get_ipython().magic(u'timeit')
# ----> 3 data=statcast()
#
# /Users/irarickman/anaconda2/lib/python2.7/site-packages/pybaseball/statcast.pyc in statcast(start_dt, end_dt, team, verbose)
#     201             data = large_request(start_dt,end_dt,d1,d2,step=small_query_threshold,verbose=verbose)
#     202
# --> 203         data = postprocessing(data, team)
#     204         return data
#     205
#
# /Users/irarickman/anaconda2/lib/python2.7/site-packages/pybaseball/statcast.pyc in postprocessing(data, team)
#     153                     'fld_score','post_away_score','post_home_score','post_bat_score','post_fld_score']
#     154
# --> 155     data[numeric_cols] = data[numeric_cols].astype(float)
#     156
# ...

# %%
data.shape
# Out:
# (3815, 90)

# %%
data[data.events.notnull()].shape
# Out:
# (976, 90)

# %% [markdown]
# ### Remaining Steps
#
# 3. Spit out the X, y, z stats to hit .300 or whichever
# 4. Label final averages
# 5. Add reference lines for milestones - mendoza line, league average, team average, .300, .400
# 7. Finalize auto update of google sheet
# 8. Add hyperlink to player page?
# 9. Add Game opponent for each game date on tooltip
# 10. Add Number of remaining opponents and average against them this season
