# %%
import pandas as pd
from pybaseball import statcast
from pybaseball import schedule_and_record
from datetime import datetime
import time
pd.options.display.max_rows=100
pd.options.display.max_columns=100

# %%
df1=pd.read_csv("abs_5-11.csv")
df2=pd.read_csv("abs_6-24.csv")

# %%
df1.shape,df2.shape
# Out:
# ((38831, 89), (40000, 89))

# %%
df=pd.concat([df1,df2],axis=0).reset_index(drop=True)

# %%
df.player_name.nunique()
# Out:
# 777

# %%
df.events.value_counts()
# Out:
# field_out                    34974
# strikeout                    19678
# single                       12281
# double                        3980
# home_run                      2635
# force_out                     1750
# grounded_into_double_play     1682
# sac_fly                        564
# triple                         401
# sac_bunt                       383
# double_play                    213
# fielders_choice_out            149
# strikeout_double_play           86
# fielders_choice                 47
# sac_fly_double_play              6
# triple_play                      1
# sac_bunt_double_play             1
# Name: events, dtype: int64

# %%
df.events.isnull().sum()
# Out:
# 0

# %%
df['hit']=df.events.apply(lambda x: 1 if x in ["single",'double','home_run','triple'] else 0)
df['ab']=df.events.apply(lambda x: 0 if x in ["sac_fly",'sac_bunt','sac_fly_double_play','sac_bunt_double_play'] else 1)

# %%
df['date']=pd.to_datetime(df['game_date'],infer_datetime_format=True)
sorted(df.date.unique())
# Out:
# [numpy.datetime64('2018-03-29T00:00:00.000000000'),
#  numpy.datetime64('2018-03-30T00:00:00.000000000'),
#  numpy.datetime64('2018-03-31T00:00:00.000000000'),
#  numpy.datetime64('2018-04-01T00:00:00.000000000'),
#  numpy.datetime64('2018-04-02T00:00:00.000000000'),
#  numpy.datetime64('2018-04-03T00:00:00.000000000'),
#  numpy.datetime64('2018-04-04T00:00:00.000000000'),
#  numpy.datetime64('2018-04-05T00:00:00.000000000'),
#  numpy.datetime64('2018-04-06T00:00:00.000000000'),
#  numpy.datetime64('2018-04-07T00:00:00.000000000'),
#  numpy.datetime64('2018-04-08T00:00:00.000000000'),
#  numpy.datetime64('2018-04-09T00:00:00.000000000'),
#  numpy.datetime64('2018-04-10T00:00:00.000000000'),
#  numpy.datetime64('2018-04-11T00:00:00.000000000'),
#  numpy.datetime64('2018-04-12T00:00:00.000000000'),
#  numpy.datetime64('2018-04-13T00:00:00.000000000'),
#  numpy.datetime64('2018-04-14T00:00:00.000000000'),
#  numpy.datetime64('2018-04-15T00:00:00.000000000'),
#  numpy.datetime64('2018-04-16T00:00:00.000000000'),
#  numpy.datetime64('2018-04-17T00:00:00.000000000'),
#  numpy.datetime64('2018-04-18T00:00:00.000000000'),
#  numpy.datetime64('2018-04-19T00:00:00.000000000'),
#  numpy.datetime64('2018-04-20T00:00:00.000000000'),
#  numpy.datetime64('2018-04-21T00:00:00.000000000'),
#  numpy.datetime64('2018-04-22T00:00:00.000000000'),
#  numpy.datetime64('2018-04-23T00:00:00.000000000'),
#  numpy.datetime64('2018-04-24T00:00:00.000000000'),
#  numpy.datetime64('2018-04-25T00:00:00.000000000'),
#  numpy.datetime64('2018-04-26T00:00:00.000000000'),
#  numpy.datetime64('2018-04-27T00:00:00.000000000'),
#  numpy.datetime64('2018-04-28T00:00:00.000000000'),
#  numpy.datetime64('2018-04-29T00:00:00.000000000'),
#  numpy.datetime64('2018-04-30T00:00:00.000000000'),
#  numpy.datetime64('2018-05-01T00:00:00.000000000'),
#  numpy.datetime64('2018-05-02T00:00:00.000000000'),
#  numpy.datetime64('2018-05-03T00:00:00.000000000'),
#  numpy.datetime64('2018-05-04T00:00:00.000000000'),
#  numpy.datetime64('2018-05-05T00:00:00.000000000'),
#  numpy.datetime64('2018-05-06T00:00:00.000000000'),
#  numpy.datetime64('2018-05-07T00:00:00.000000000'),
#  numpy.datetime64('2018-05-08T00:00:00.000000000'),
#  numpy.datetime64('2018-05-09T00:00:00.000000000'),
#  numpy.datetime64('2018-05-10T00:00:00.000000000'),
#  numpy.datetime64('2018-05-11T00:00:00.000000000'),
#  numpy.datetime64('2018-05-12T00:00:00.000000000'),
#  numpy.datetime64('2018-05-13T00:00:00.000000000'),
#  numpy.datetime64('2018-05-14T00:00:00.000000000'),
#  numpy.datetime64('2018-05-15T00:00:00.000000000'),
#  numpy.datetime64('2018-05-16T00:00:00.000000000'),
#  numpy.datetime64('2018-05-17T00:00:00.000000000'),
#  numpy.datetime64('2018-05-18T00:00:00.000000000'),
#  numpy.datetime64('2018-05-19T00:00:00.000000000'),
#  numpy.datetime64('2018-05-20T00:00:00.000000000'),
#  numpy.datetime64('2018-05-21T00:00:00.000000000'),
#  numpy.datetime64('2018-05-22T00:00:00.000000000'),
#  numpy.datetime64('2018-05-23T00:00:00.000000000'),
#  numpy.datetime64('2018-05-24T00:00:00.000000000'),
#  numpy.datetime64('2018-05-25T00:00:00.000000000'),
#  numpy.datetime64('2018-05-26T00:00:00.000000000'),
#  numpy.datetime64('2018-05-27T00:00:00.000000000'),
#  numpy.datetime64('2018-05-28T00:00:00.000000000'),
#  numpy.datetime64('2018-05-29T00:00:00.000000000'),
#  numpy.datetime64('2018-05-30T00:00:00.000000000'),
#  numpy.datetime64('2018-05-31T00:00:00.000000000'),
#  numpy.datetime64('2018-06-01T00:00:00.000000000'),
#  numpy.datetime64('2018-06-02T00:00:00.000000000'),
#  numpy.datetime64('2018-06-03T00:00:00.000000000'),
#  numpy.datetime64('2018-06-04T00:00:00.000000000'),
#  numpy.datetime64('2018-06-05T00:00:00.000000000'),
#  numpy.datetime64('2018-06-06T00:00:00.000000000'),
#  numpy.datetime64('2018-06-07T00:00:00.000000000'),
#  numpy.datetime64('2018-06-08T00:00:00.000000000'),
#  numpy.datetime64('2018-06-09T00:00:00.000000000'),
#  numpy.datetime64('2018-06-10T00:00:00.000000000'),
#  numpy.datetime64('2018-06-11T00:00:00.000000000'),
#  numpy.datetime64('2018-06-12T00:00:00.000000000'),
#  numpy.datetime64('2018-06-13T00:00:00.000000000'),
#  numpy.datetime64('2018-06-14T00:00:00.000000000'),
#  numpy.datetime64('2018-06-15T00:00:00.000000000'),
#  numpy.datetime64('2018-06-16T00:00:00.000000000'),
#  numpy.datetime64('2018-06-17T00:00:00.000000000'),
#  numpy.datetime64('2018-06-18T00:00:00.000000000'),
#  numpy.datetime64('2018-06-19T00:00:00.000000000'),
#  numpy.datetime64('2018-06-20T00:00:00.000000000'),
#  numpy.datetime64('2018-06-21T00:00:00.000000000'),
#  numpy.datetime64('2018-06-22T00:00:00.000000000'),
#  numpy.datetime64('2018-06-23T00:00:00.000000000'),
#  numpy.datetime64('2018-06-24T00:00:00.000000000')]

# %%
df['htd']=df.sort_values(['date','inning'],ascending=True).groupby(['player_name']).hit.cumsum()
df['abtd']=df.sort_values(['date','inning'],ascending=True).groupby(['player_name']).ab.cumsum()
df['avg']=df.htd/df.abtd

# %%
df[['player_name','date','inning','hit','ab','htd','abtd','avg']].sort_values(['player_name','date','inning'],ascending=True).head(100)
# Out:
#         player_name       date  inning  hit  ab  htd  abtd       avg
# 34342     A.J. Cole 2018-04-03       2    1   1    1     1  1.000000
# 34191     A.J. Cole 2018-04-03       3    0   1    1     2  0.500000
# 27480     A.J. Cole 2018-04-11       3    0   0    1     2  0.500000
# 27261     A.J. Cole 2018-04-11       5    0   1    1     3  0.333333
# 35206    A.J. Ellis 2018-04-02       2    0   1    0     1  0.000000
# 34810    A.J. Ellis 2018-04-02       6    0   1    0     2  0.000000
# 34643    A.J. Ellis 2018-04-02       8    0   1    0     3  0.000000
# 34333    A.J. Ellis 2018-04-03       2    0   1    0     4  0.000000
# 34102    A.J. Ellis 2018-04-03       5    1   1    1     5  0.200000
# 33956    A.J. Ellis 2018-04-03       6    0   1    1     6  0.166667
# 31349    A.J. Ellis 2018-04-07       3    1   1    2     7  0.285714
# 31135    A.J. Ellis 2018-04-07       5    0   0    2     7  0.285714
# 30835    A.J. Ellis 2018-04-07       7    0   1    2     8  0.250000
# 30572    A.J. Ellis 2018-04-07      10    0   1    2     9  0.222222
# 27444    A.J. Ellis 2018-04-11       3    0   1    2    10  0.200000
# 24911    A.J. Ellis 2018-04-14       2    0   1    2    11  0.181818
# 24677    A.J. Ellis 2018-04-14       5    1   1    3    12  0.250000
# 24437    A.J. Ellis 2018-04-14       7    0   1    3    13  0.230769
# 22836    A.J. Ellis 2018-04-17       2    0   1    3    14  0.214286
# 22545    A.J. Ellis 2018-04-17       5    0   1    3    15  0.200000
# 22319    A.J. Ellis 2018-04-17       7    0   1    3    16  0.187500
# 17187    A.J. Ellis 2018-04-23       2    0   1    3    17  0.176471
# 17053    A.J. Ellis 2018-04-23       4    0   1    3    18  0.166667
# 16900    A.J. Ellis 2018-04-23       7    0   1    3    19  0.157895
# 16747    A.J. Ellis 2018-04-23       8    0   1    3    20  0.150000
# 11552    A.J. Ellis 2018-04-29       2    1   1    4    21  0.190476
# 11319    A.J. Ellis 2018-04-29       4    0   1    4    22  0.181818
# 11022    A.J. Ellis 2018-04-29       6    0   1    4    23  0.173913
# 10815    A.J. Ellis 2018-04-29       8    1   1    5    24  0.208333
# 10494    A.J. Ellis 2018-04-30       4    0   1    5    25  0.200000
# 10335    A.J. Ellis 2018-04-30       6    0   0    5    25  0.200000
# 10189    A.J. Ellis 2018-04-30       8    1   1    6    26  0.230769
# 50554    A.J. Ellis 2018-06-12       4    1   1   22    70  0.314286
# 50328    A.J. Ellis 2018-06-12       7    0   0   22    70  0.314286
# 48744    A.J. Ellis 2018-06-14       3    1   1   23    71  0.323944
# 48566    A.J. Ellis 2018-06-14       6    1   1   24    72  0.333333
# 48449    A.J. Ellis 2018-06-14       8    0   1   24    73  0.328767
# 47091    A.J. Ellis 2018-06-16       2    1   1   25    74  0.337838
# 46798    A.J. Ellis 2018-06-16       5    0   1   25    75  0.333333
# 46525    A.J. Ellis 2018-06-16       8    0   1   25    76  0.328947
# 43218    A.J. Ellis 2018-06-20       3    1   1   26    77  0.337662
# 43046    A.J. Ellis 2018-06-20       4    0   1   26    78  0.333333
# 42783    A.J. Ellis 2018-06-20       7    0   1   26    79  0.329114
# 42659    A.J. Ellis 2018-06-20       9    0   1   26    80  0.325000
# 42550    A.J. Ellis 2018-06-21       3    0   1   26    81  0.320988
# 42261    A.J. Ellis 2018-06-21       8    0   1   26    82  0.317073
# 40711    A.J. Ellis 2018-06-23       3    1   1   27    83  0.325301
# 40500    A.J. Ellis 2018-06-23       5    1   1   28    84  0.333333
# 40041    A.J. Ellis 2018-06-23       9    1   1   29    85  0.341176
# 38744  A.J. Pollock 2018-03-29       1    1   1    1     1  1.000000
# 38546  A.J. Pollock 2018-03-29       3    0   1    1     2  0.500000
# 38190  A.J. Pollock 2018-03-29       6    0   1    1     3  0.333333
# 38075  A.J. Pollock 2018-03-29       7    0   1    1     4  0.250000
# 37850  A.J. Pollock 2018-03-30       1    1   1    2     5  0.400000
# 37661  A.J. Pollock 2018-03-30       3    1   1    3     6  0.500000
# 37506  A.J. Pollock 2018-03-30       4    0   1    3     7  0.428571
# 37328  A.J. Pollock 2018-03-30       6    0   1    3     8  0.375000

# %%
df['player_team']=df.apply(lambda x: x.home_team if x.inning_topbot=="Bot" else x.away_team,axis=1)

# %%
teams=df.player_team.unique()
fixers={"WSH":"WSN","CWS":"CHW"}
teams_fixed=[x if x not in fixers.keys() else fixers[x] for x in teams]

# %%
team_schedule={}
missed=[]
for t in teams_fixed:
    try:
        d=schedule_and_record(2018,t)
        d['fix_date']=d.Date.str.replace("\(\d\)","").str.strip() + " 2018"
        d['game_date']=pd.to_datetime(d.fix_date.apply(lambda x: datetime.strptime(x,"%A, %b %d %Y")).apply(lambda x: x.strftime("%Y-%m-%d")),infer_datetime_format=True)
        d['place']=d.Home_Away.apply(lambda x: "Home" if x=="Home" else "Away")
        d2=d[d.game_date>=datetime.today()][['Tm','place',"Opp","game_date"]]
        team_schedule[t]=d2
    except ValueError:
        print(t)
        missed.append(t)

# %%
for r in missed:
    try:
        d=schedule_and_record(2018,r)
        d['fix_date']=d.Date + " 2018"
        d['game_date']=pd.to_datetime(d.fix_date.apply(lambda x: datetime.strptime(x,"%A, %b %d %Y")).apply(lambda x: x.strftime("%Y-%m-%d")),infer_datetime_format=True)
        d['place']=d.Home_Away.apply(lambda x: "Home" if x=="Home" else "Away")
        d2=d[d.game_date>=datetime.today()][['Tm','place',"Opp","game_date"]]
        team_schedule[r]=d2
    except ValueError:
        print(r)
# Out:
# CWS
# CLE
# TOR
# CHC
# KC
# SF
# PIT
# LAD
# MIN
# NYY
# CIN
# OAK
# ATL
# NYM
# TB
# BAL
# WSH
# SEA
# DET

# %%
missing_schedules={}
for r in missed:
    try:
        d=schedule_and_record(2018,r)
        missing_schedules[r]=d
    except ValueError:
        print(r)
# Out:
# CWS
# WSH

# %%
for r in missing_schedules.keys():
    d=missing_schedules[r]
    d['fix_date']=d.Date.str.replace("\(\d\)","").str.strip() + " 2018"
    try:
        d['game_date']=pd.to_datetime(d.fix_date.apply(lambda x: datetime.strptime(x,"%A, %b %d %Y")).apply(lambda x: x.strftime("%Y-%m-%d")),infer_datetime_format=True)
    except ValueError:
        print("didn't work for {}".format(r))
# Out:
# didn't work for KC
# didn't work for DET
# didn't work for CHC
# didn't work for MIN
# didn't work for TOR
# didn't work for CLE
# didn't work for ATL
# didn't work for TB
# didn't work for OAK
# didn't work for CIN
# didn't work for LAD
# didn't work for NYY
# didn't work for SEA
# didn't work for NYM
# didn't work for BAL
# didn't work for PIT
# didn't work for SF

# %%
missing
# Out:
# [array([u'WSN', u'BAL', u'PIT', u'NYM', u'MIA', u'SDP', u'LAD', u'CIN',
#         u'BOS', u'ARI', u'TOR', u'CHC', u'ATL', u'COL'], dtype=object),
#  array([u'CIN', u'MIN', u'ATL', u'MIA', u'PIT', u'LAD', u'WSN', u'SFG',
#         u'COL', u'SDP', u'CHC', u'STL', u'DET'], dtype=object),
#  array([u'ATL', u'ARI', u'SFG', u'CHW', u'CIN', u'CHC', u'COL', u'PIT',
#         u'MIA', u'KCR', u'WSN', u'MIL', u'LAD', u'DET'], dtype=object),
#  array([u'NYY', u'WSN', u'KCR', u'TEX', u'TOR', u'DET', u'BAL', u'MIN',
#         u'PHI', u'TBR', u'CLE', u'MIA', u'CHW', u'ATL', u'HOU', u'NYM'], dtype=object),
#  array([u'BAL', u'SEA', u'LAD', u'HOU', u'CHW', u'TBR', u'CLE', u'DET',
#         u'OAK', u'SDP', u'TEX', u'ARI', u'COL'], dtype=object),
#  array([u'CHW', u'HOU', u'DET', u'BOS', u'BAL', u'CLE', u'OAK', u'ARI',
#         u'SEA', u'NYY', u'LAA', u'SFG', u'LAD', u'MIN', u'SDP', u'TBR'], dtype=object),
#  array([u'NYM', u'TBR', u'WSN', u'MIL', u'PHI', u'ATL', u'STL', u'NYY',
#         u'BOS', u'TOR', u'PIT', u'CIN'], dtype=object),
#  array([u'TBR', u'TEX', u'CHW', u'OAK', u'DET', u'LAA', u'COL', u'SEA',
#         u'LAD', u'SFG', u'MIN', u'BOS', u'ARI', u'TOR', u'BAL'], dtype=object),
#  array([u'SFG', u'STL', u'SDP', u'COL', u'ATL', u'CHC', u'TEX', u'PHI',
#         u'CIN', u'LAA', u'SEA', u'LAD', u'HOU'], dtype=object),
#  array([u'LAD', u'SFG', u'SEA', u'ARI', u'HOU', u'OAK', u'STL', u'MIL',
#         u'PIT', u'ATL', u'SDP', u'LAA', u'PHI', u'WSN'], dtype=object),
#  array([u'PIT', u'OAK', u'ARI', u'LAD', u'CHC', u'PHI', u'NYM', u'SFG',
#         u'MIL', u'LAA', u'COL', u'SEA', u'CIN', u'TEX'], dtype=object)]

# %%
schedule_and_record(2018,"CHW")
# Out:
#                      Date   Tm Home_Away  Opp   W/L     R    RA   Inn    W-L  \
# 1        Thursday, Mar 29  CHW         @  KCR     W  14.0   7.0   9.0    1-0
# 2        Saturday, Mar 31  CHW         @  KCR     W   4.0   3.0   9.0    2-0
# 3           Monday, Apr 2  CHW         @  TOR     L   2.0   4.0   9.0    2-1
# 4          Tuesday, Apr 3  CHW         @  TOR     L   5.0  14.0   9.0    2-2
# 5        Wednesday, Apr 4  CHW         @  TOR     W   4.0   3.0   9.0    3-2
# 6         Thursday, Apr 5  CHW      Home  DET     L   7.0   9.0  10.0    3-3
# 7         Saturday, Apr 7  CHW      Home  DET     L   1.0   6.0   9.0    3-4
# 8           Sunday, Apr 8  CHW      Home  DET     L   0.0   1.0   9.0    3-5
# 9           Monday, Apr 9  CHW      Home  TBR     L   4.0   5.0   9.0    3-6
# 10        Tuesday, Apr 10  CHW      Home  TBR     L   5.0   6.0   9.0    3-7
# 11      Wednesday, Apr 11  CHW      Home  TBR     W   2.0   1.0   9.0    4-7
# 12       Thursday, Apr 12  CHW         @  MIN     L   0.0   4.0   9.0    4-8
# 13         Monday, Apr 16  CHW         @  OAK     L   1.0   8.0   9.0    4-9
# 14        Tuesday, Apr 17  CHW         @  OAK     L   2.0  10.0   9.0   4-10
# 15      Wednesday, Apr 18  CHW         @  OAK  L-wo  11.0  12.0  14.0   4-11
# 16         Friday, Apr 20  CHW      Home  HOU     L   0.0  10.0   9.0   4-12
# 17       Saturday, Apr 21  CHW      Home  HOU     L   1.0  10.0   9.0   4-13
# 18         Sunday, Apr 22  CHW      Home  HOU     L   1.0   7.0   9.0   4-14
# 19         Monday, Apr 23  CHW      Home  SEA     W  10.0   4.0   9.0   5-14
# 20        Tuesday, Apr 24  CHW      Home  SEA     L   0.0   1.0   9.0   5-15
# 21      Wednesday, Apr 25  CHW      Home  SEA     L   3.0   4.0   9.0   5-16
# 22       Thursday, Apr 26  CHW         @  KCR     W   6.0   3.0   9.0   6-16
# 23         Friday, Apr 27  CHW         @  KCR     W   7.0   4.0  11.0   7-16
# 24   Saturday, Apr 28 (1)  CHW         @  KCR     W   8.0   0.0   9.0   8-16
# 25   Saturday, Apr 28 (2)  CHW         @  KCR     L   2.0   5.0   9.0   8-17
# 26         Sunday, Apr 29  CHW         @  KCR     L   4.0   5.0   9.0   8-18
# 27         Tuesday, May 1  CHW         @  STL  L-wo   2.0   3.0   9.0   8-19
# 28       Wednesday, May 2  CHW         @  STL     L   2.0   3.0   9.0   8-20
# 29        Thursday, May 3  CHW      Home  MIN  W-wo   6.0   5.0   9.0   9-20
# 30          Friday, May 4  CHW      Home  MIN     L   4.0   6.0   9.0   9-21
# 31        Saturday, May 5  CHW      Home  MIN     L   4.0   8.0   9.0   9-22
# 32          Sunday, May 6  CHW      Home  MIN     L   3.0   5.0   9.0   9-23
# 33         Tuesday, May 8  CHW      Home  PIT     L   6.0  10.0   9.0   9-24
# 34       Wednesday, May 9  CHW      Home  PIT     L   5.0   6.0   9.0   9-25
# 35         Friday, May 11  CHW         @  CHC     L   2.0  11.0   9.0   9-26
# 36       Saturday, May 12  CHW         @  CHC     L   4.0   8.0   9.0   9-27
# 37         Sunday, May 13  CHW         @  CHC     W   5.0   3.0   9.0  10-27
# 38        Tuesday, May 15  CHW         @  PIT     L   0.0   7.0   9.0  10-28
# 39      Wednesday, May 16  CHW         @  PIT     L   2.0   3.0   9.0  10-29
# 40       Thursday, May 17  CHW      Home  TEX     W   4.0   2.0   9.0  11-29
# 41         Friday, May 18  CHW      Home  TEX     L   5.0  12.0   9.0  11-30
# 42       Saturday, May 19  CHW      Home  TEX     W   5.0   3.0   9.0  12-30
# 43         Sunday, May 20  CHW      Home  TEX     W   3.0   0.0   9.0  13-30
# 44         Monday, May 21  CHW      Home  BAL     L   2.0   3.0   9.0  13-31
# 45        Tuesday, May 22  CHW      Home  BAL     W   3.0   2.0   9.0  14-31
# 46      Wednesday, May 23  CHW      Home  BAL     W  11.0   1.0   9.0  15-31
# 47       Thursday, May 24  CHW      Home  BAL     L   3.0   9.0   9.0  15-32
# 48         Friday, May 25  CHW         @  DET     L   4.0   5.0   9.0  15-33
# 49       Saturday, May 26  CHW         @  DET     W   8.0   4.0   9.0  16-33
# 50         Sunday, May 27  CHW         @  DET     L   2.0   3.0   9.0  16-34
# ..                    ...  ...       ...  ...   ...   ...   ...   ...    ...
# 113        Tuesday, Aug 7  CHW      Home  NYY  None   NaN   NaN   NaN   None
# 114      Wednesday, Aug 8  CHW      Home  NYY  None   NaN   NaN   NaN   None
# 115        Friday, Aug 10  CHW      Home  CLE  None   NaN   NaN   NaN   None
# 116      Saturday, Aug 11  CHW      Home  CLE  None   NaN   NaN   NaN   None
# 117        Sunday, Aug 12  CHW      Home  CLE  None   NaN   NaN   NaN   None
# 118        Monday, Aug 13  CHW         @  DET  None   NaN   NaN   NaN   None
# 119       Tuesday, Aug 14  CHW         @  DET  None   NaN   NaN   NaN   None
# 120     Wednesday, Aug 15  CHW         @  DET  None   NaN   NaN   NaN   None
# 121        Friday, Aug 17  CHW      Home  KCR  None   NaN   NaN   NaN   None
# 122      Saturday, Aug 18  CHW      Home  KCR  None   NaN   NaN   NaN   None
# 123        Sunday, Aug 19  CHW      Home  KCR  None   NaN   NaN   NaN   None
# 124        Monday, Aug 20  CHW         @  MIN  None   NaN   NaN   NaN   None
# 125       Tuesday, Aug 21  CHW      Home  MIN  None   NaN   NaN   NaN   None
# 126     Wednesday, Aug 22  CHW      Home  MIN  None   NaN   NaN   NaN   None
# 127      Thursday, Aug 23  CHW         @  DET  None   NaN   NaN   NaN   None
# 128        Friday, Aug 24  CHW         @  DET  None   NaN   NaN   NaN   None
# 129      Saturday, Aug 25  CHW         @  DET  None   NaN   NaN   NaN   None
# 130        Sunday, Aug 26  CHW         @  DET  None   NaN   NaN   NaN   None
# 131        Monday, Aug 27  CHW         @  NYY  None   NaN   NaN   NaN   None
# 132       Tuesday, Aug 28  CHW         @  NYY  None   NaN   NaN   NaN   None
# 133     Wednesday, Aug 29  CHW         @  NYY  None   NaN   NaN   NaN   None
# 134      Thursday, Aug 30  CHW      Home  BOS  None   NaN   NaN   NaN   None
# 135        Friday, Aug 31  CHW      Home  BOS  None   NaN   NaN   NaN   None
# 136       Saturday, Sep 1  CHW      Home  BOS  None   NaN   NaN   NaN   None
# 137         Sunday, Sep 2  CHW      Home  BOS  None   NaN   NaN   NaN   None
# 138         Monday, Sep 3  CHW      Home  DET  None   NaN   NaN   NaN   None
# 139        Tuesday, Sep 4  CHW      Home  DET  None   NaN   NaN   NaN   None
# 140      Wednesday, Sep 5  CHW      Home  DET  None   NaN   NaN   NaN   None
# 141         Friday, Sep 7  CHW      Home  LAA  None   NaN   NaN   NaN   None
# 142       Saturday, Sep 8  CHW      Home  LAA  None   NaN   NaN   NaN   None
# 143         Sunday, Sep 9  CHW      Home  LAA  None   NaN   NaN   NaN   None
# 144        Monday, Sep 10  CHW         @  KCR  None   NaN   NaN   NaN   None
# 145       Tuesday, Sep 11  CHW         @  KCR  None   NaN   NaN   NaN   None
# 146     Wednesday, Sep 12  CHW         @  KCR  None   NaN   NaN   NaN   None
# 147        Friday, Sep 14  CHW         @  BAL  None   NaN   NaN   NaN   None
# 148      Saturday, Sep 15  CHW         @  BAL  None   NaN   NaN   NaN   None
# 149        Sunday, Sep 16  CHW         @  BAL  None   NaN   NaN   NaN   None
# 150       Tuesday, Sep 18  CHW         @  CLE  None   NaN   NaN   NaN   None
# 151     Wednesday, Sep 19  CHW         @  CLE  None   NaN   NaN   NaN   None
# 152      Thursday, Sep 20  CHW         @  CLE  None   NaN   NaN   NaN   None
# 153        Friday, Sep 21  CHW      Home  CHC  None   NaN   NaN   NaN   None
# 154      Saturday, Sep 22  CHW      Home  CHC  None   NaN   NaN   NaN   None
# 155        Sunday, Sep 23  CHW      Home  CHC  None   NaN   NaN   NaN   None
# 156        Monday, Sep 24  CHW      Home  CLE  None   NaN   NaN   NaN   None
# 157       Tuesday, Sep 25  CHW      Home  CLE  None   NaN   NaN   NaN   None
# 158     Wednesday, Sep 26  CHW      Home  CLE  None   NaN   NaN   NaN   None
# 159        Friday, Sep 28  CHW         @  MIN  None   NaN   NaN   NaN   None
# 160        Friday, Sep 28  CHW         @  MIN  None   NaN   NaN   NaN   None
# 161      Saturday, Sep 29  CHW         @  MIN  None   NaN   NaN   NaN   None
# 162        Sunday, Sep 30  CHW         @  MIN  None   NaN   NaN   NaN   None
#
#      Rank      GB        Win       Loss     Save  Time   D/N  Attendance  \
# 1     1.0  up 0.5    Shields      Duffy     None  3:26     D     36517.0
# 2     1.0  up 1.0   Farquhar     Maurer    Soria  2:54     N     17564.0
# 3     1.0  up 0.5         Oh   Farquhar    Osuna  2:51     N     16629.0
# 4     1.0    Tied       Happ   Gonzalez     None  3:27     N     17451.0
# 47    5.0     8.5      Bundy    Giolito     None  3:00     D     19147.0
# 48    5.0     8.5     Farmer     Rondon   Greene  2:51     N     24648.0
# 49    4.0     8.5   Santiago    Liriano     None  3:16     D     27032.0
# 50    5.0     9.5      Hardy    Shields   Greene  2:17     D     23419.0
# ..    ...     ...        ...        ...      ...   ...   ...         ...
# 113   NaN    None       None       None     None  None  None         NaN
# 114   NaN    None       None       None     None  None  None         NaN
# 115   NaN    None       None       None     None  None  None         NaN
# 116   NaN    None       None       None     None  None  None         NaN
# 117   NaN    None       None       None     None  None  None         NaN
# 118   NaN    None       None       None     None  None  None         NaN
# 119   NaN    None       None       None     None  None  None         NaN
# 120   NaN    None       None       None     None  None  None         NaN
# 121   NaN    None       None       None     None  None  None         NaN
# 122   NaN    None       None       None     None  None  None         NaN
# 123   NaN    None       None       None     None  None  None         NaN
# 124   NaN    None       None       None     None  None  None         NaN
# 125   NaN    None       None       None     None  None  None         NaN
# 126   NaN    None       None       None     None  None  None         NaN
# 127   NaN    None       None       None     None  None  None         NaN
# 128   NaN    None       None       None     None  None  None         NaN
# 129   NaN    None       None       None     None  None  None         NaN
# 130   NaN    None       None       None     None  None  None         NaN
# 131   NaN    None       None       None     None  None  None         NaN
# 132   NaN    None       None       None     None  None  None         NaN
# 133   NaN    None       None       None     None  None  None         NaN
# 134   NaN    None       None       None     None  None  None         NaN
# 135   NaN    None       None       None     None  None  None         NaN
# 136   NaN    None       None       None     None  None  None         NaN
# 137   NaN    None       None       None     None  None  None         NaN
# 138   NaN    None       None       None     None  None  None         NaN
# 139   NaN    None       None       None     None  None  None         NaN
# 140   NaN    None       None       None     None  None  None         NaN
# 141   NaN    None       None       None     None  None  None         NaN
# 142   NaN    None       None       None     None  None  None         NaN
# 143   NaN    None       None       None     None  None  None         NaN
# 144   NaN    None       None       None     None  None  None         NaN
# 145   NaN    None       None       None     None  None  None         NaN
# 146   NaN    None       None       None     None  None  None         NaN
# 147   NaN    None       None       None     None  None  None         NaN
# 148   NaN    None       None       None     None  None  None         NaN
# 149   NaN    None       None       None     None  None  None         NaN
# 150   NaN    None       None       None     None  None  None         NaN
# 151   NaN    None       None       None     None  None  None         NaN
# 152   NaN    None       None       None     None  None  None         NaN
# 153   NaN    None       None       None     None  None  None         NaN
# 154   NaN    None       None       None     None  None  None         NaN
# 155   NaN    None       None       None     None  None  None         NaN
# 156   NaN    None       None       None     None  None  None         NaN
# 157   NaN    None       None       None     None  None  None         NaN
# 158   NaN    None       None       None     None  None  None         NaN
# 159   NaN    None       None       None     None  None  None         NaN
# 160   NaN    None       None       None     None  None  None         NaN
# 161   NaN    None       None       None     None  None  None         NaN
# 162   NaN    None       None       None     None  None  None         NaN
#
#      Streak Orig. Scheduled
# 1       1.0            None
# 2       2.0            None
# 3      -1.0            None
# 4      -2.0            None
# 5       1.0            None
# 6      -1.0            None
# 7      -2.0            None
# 8      -3.0            None
# 9      -4.0            None
# 10     -5.0            None
# 11      1.0            None
# 12     -1.0            None
# 13     -2.0            None
# 14     -3.0            None
# 15     -4.0            None
# 16     -5.0            None
# 17     -6.0            None
# 18     -7.0            None
# 19      1.0            None
# 20     -1.0            None
# 21     -2.0            None
# 22      1.0            None
# 23      2.0            None
# 24      3.0            None
# 25     -1.0            None
# 26     -2.0            None
# 27     -3.0            None
# 28     -4.0            None
# 29      1.0            None
# 30     -1.0            None
# 31     -2.0            None
# 32     -3.0            None
# 33     -4.0            None
# 34     -5.0            None
# 35     -6.0            None
# 36     -7.0            None
# 37      1.0            None
# 38     -1.0            None
# 39     -2.0            None
# 40      1.0            None
# 41     -1.0            None
# 42      1.0            None
# 43      2.0            None
# 44     -1.0            None
# 45      1.0            None
# 46      2.0            None
# 47     -1.0            None
# 48     -2.0            None
# 49      1.0            None
# 50     -1.0            None
# ..      ...             ...
# 113     NaN            None
# 114     NaN            None
# 115     NaN            None
# 116     NaN            None
# 117     NaN            None
# 118     NaN            None
# 119     NaN            None
# 120     NaN            None
# 121     NaN            None
# 122     NaN            None
# 123     NaN            None
# 124     NaN            None
# 125     NaN            None
# 126     NaN            None
# 127     NaN            None
# 128     NaN            None
# 129     NaN            None
# 130     NaN            None
# 131     NaN            None
# 132     NaN            None
# 133     NaN            None
# 134     NaN            None
# 135     NaN            None
# 136     NaN            None
# 137     NaN            None
# 138     NaN            None
# 139     NaN            None
# 140     NaN            None
# 141     NaN            None
# 142     NaN            None
# 143     NaN            None
# 144     NaN            None
# 145     NaN            None
# 146     NaN            None
# 147     NaN            None
# 148     NaN            None
# 149     NaN            None
# 150     NaN            None
# 151     NaN            None
# 152     NaN            None
# 153     NaN            None
# 154     NaN            None
# 155     NaN            None
# 156     NaN            None
# 157     NaN            None
# 158     NaN            None
# 159     NaN            None
# 160     NaN            None
# 161     NaN            None
# 162     NaN            None
#
# [162 rows x 19 columns]

# %%
set([y for x in missing for y in x])
team_dict={"CWS":"CHW",'CLE':'CLE'}
# Out:
# {u'ARI',
#  u'ATL',
#  u'BAL',
#  u'BOS',
#  u'CHC',
#  u'CHW',
#  u'CIN',
#  u'CLE',
#  u'COL',
#  u'DET',
#  u'HOU',
#  u'KCR',
#  u'LAA',
#  u'LAD',
#  u'MIA',
#  u'MIL',
#  u'MIN',
#  u'NYM',
#  u'NYY',
#  u'OAK',
#  u'PHI',
#  u'PIT',
#  u'SDP',
#  u'SEA',
#  u'SFG',
#  u'STL',
#  u'TBR',
#  u'TEX',
#  u'TOR',
#  u'WSN'}

# %%
team_schedule['MIL']
# Out:
#       Tm place  Opp  game_date
# 78   MIL  Home  KCR 2018-06-26
# 79   MIL  Home  KCR 2018-06-27
# 80   MIL  Away  CIN 2018-06-28
# 81   MIL  Away  CIN 2018-06-29
# 82   MIL  Away  CIN 2018-06-30
# 83   MIL  Away  CIN 2018-07-01
# 84   MIL  Home  MIN 2018-07-02
# 85   MIL  Home  MIN 2018-07-03
# 86   MIL  Home  MIN 2018-07-04
# 87   MIL  Home  ATL 2018-07-05
# 88   MIL  Home  ATL 2018-07-06
# 89   MIL  Home  ATL 2018-07-07
# 161  MIL  Home  DET 2018-09-29
# 162  MIL  Home  DET 2018-09-30

# %%
a=d.Date[1] + " 2018"
g=datetime.strptime(a,"%A, %b %d %Y")
print(g.strftime("%Y-%m-%d"))
# Out:
# 2018-03-29

# %%
d['fix_date']=d.Date + " 2018"
d['game_date']=pd.to_datetime(d.fix_date.apply(lambda x: datetime.strptime(x,"%A, %b %d %Y")).apply(lambda x: x.strftime("%Y-%m-%d")),infer_datetime_format=True)

# %%
d.game_date
# Out:
# 1     2018-03-29
# 2     2018-03-30
# 3     2018-03-31
# 4     2018-04-02
# 5     2018-04-03
# 6     2018-04-04
# 7     2018-04-05
# 8     2018-04-06
# 9     2018-04-07
# 10    2018-04-08
# 11    2018-04-09
# 12    2018-04-10
# 13    2018-04-11
# 14    2018-04-12
# 15    2018-04-13
# 16    2018-04-14
# 17    2018-04-15
# 18    2018-04-16
# 19    2018-04-17
# 20    2018-04-18
# 21    2018-04-20
# 22    2018-04-21
# 23    2018-04-22
# 24    2018-04-23
# 25    2018-04-24
# 26    2018-04-25
# 27    2018-04-27
# 28    2018-04-28
# 29    2018-04-29
# 30    2018-04-30
# 31    2018-05-01
# 32    2018-05-02
# 33    2018-05-04
# 34    2018-05-05
# 35    2018-05-06
# 36    2018-05-08
# 37    2018-05-09
# 38    2018-05-10
# 39    2018-05-11
# 40    2018-05-12
# 41    2018-05-13
# 42    2018-05-14
# 43    2018-05-15
# 44    2018-05-17
# 45    2018-05-18
# 46    2018-05-19
# 47    2018-05-20
# 48    2018-05-21
# 49    2018-05-22
# 50    2018-05-23
#          ...
# 113   2018-08-07
# 114   2018-08-08
# 115   2018-08-09
# 116   2018-08-10
# 117   2018-08-11
# 118   2018-08-12
# 119   2018-08-14
# 120   2018-08-15
# 121   2018-08-16
# 122   2018-08-17
# 123   2018-08-18
# 124   2018-08-19
# 125   2018-08-21
# 126   2018-08-22
# 127   2018-08-23
# 128   2018-08-24
# 129   2018-08-25
# 130   2018-08-26
# 131   2018-08-27
# 132   2018-08-28
# 133   2018-08-30
# 134   2018-08-31
# 135   2018-09-01
# 136   2018-09-02
# 137   2018-09-03
# 138   2018-09-04
# 139   2018-09-05
# 140   2018-09-07
# 141   2018-09-08
# 142   2018-09-09
# 143   2018-09-10
# 144   2018-09-11
# 145   2018-09-12
# 146   2018-09-13
# 147   2018-09-14
# 148   2018-09-15
# 149   2018-09-16
# 150   2018-09-17
# 151   2018-09-18
# 152   2018-09-19
# 153   2018-09-21
# 154   2018-09-22
# 155   2018-09-23
# 156   2018-09-24
# 157   2018-09-25
# 158   2018-09-26
# 159   2018-09-27
# 160   2018-09-28
# 161   2018-09-29
# 162   2018-09-30
# Name: game_date, Length: 162, dtype: datetime64[ns]

# %%
d['game_date']=pd.to_datetime(d['Date'],infer_datetime_format=True)
d
# Out:
# ---------------------------------------------------------------------------
# OutOfBoundsDatetime                       Traceback (most recent call last)
# <ipython-input-73-04717884a87d> in <module>()
# ----> 1 d['game_date']=pd.to_datetime(d['Date'],infer_datetime_format=True)
#       2 d
#
# /Users/irarickman/anaconda2/lib/python2.7/site-packages/pandas/core/tools/datetimes.pyc in to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, unit, infer_datetime_format, origin)
#     371     elif isinstance(arg, ABCSeries):
#     372         from pandas import Series
# --> 373         values = _convert_listlike(arg._values, True, format)
#     374         result = Series(values, index=arg.index, name=arg.name)
#     375     elif isinstance(arg, (ABCDataFrame, MutableMapping)):
#
# /Users/irarickman/anaconda2/lib/python2.7/site-packages/pandas/core/tools/datetimes.pyc in _convert_listlike(arg, box, format, name, tz)
#     304                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#     305             except (ValueError, TypeError):
# --> 306                 raise e
#     307
#     308     if arg is None:
#
# OutOfBoundsDatetime: Out of bounds nanosecond timestamp: 1-03-29 00:00:00

# %%
df.to_csv("all_abs_edit.csv")

# %%
## statcast test
# %timeit
data=statcast()
# Out:
# Warning: no date range supplied. Returning yesterday's Statcast data. For a different date range, try get_statcast(start_dt, end_dt).
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-63bb5460ed4c> in <module>()
#       1 ## statcast test
#       2 get_ipython().magic(u'timeit')
# ----> 3 data=statcast()
#
# /Users/irarickman/anaconda2/lib/python2.7/site-packages/pybaseball/statcast.pyc in statcast(start_dt, end_dt, team, verbose)
#     201             data = large_request(start_dt,end_dt,d1,d2,step=small_query_threshold,verbose=verbose)
#     202
# --> 203         data = postprocessing(data, team)
#     204         return data
#     205
#
# /Users/irarickman/anaconda2/lib/python2.7/site-packages/pybaseball/statcast.pyc in postprocessing(data, team)
#     153                     'fld_score','post_away_score','post_home_score','post_bat_score','post_fld_score']
#     154
# --> 155     data[numeric_cols] = data[numeric_cols].astype(float)
#     156
#     157     # convert date col to datetime data type and sort so that this returns in an order that makes sense (by date and game)
#
# /Users/irarickman/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __setitem__(self, key, value)
#    2512
#    2513         if isinstance(key, (Series, np.ndarray, list, Index)):
# -> 2514             self._setitem_array(key, value)
#    2515         elif isinstance(key, DataFrame):
#    2516             self._setitem_frame(key, value)
#
# /Users/irarickman/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _setitem_array(self, key, value)
#    2538                     raise ValueError('Columns must be same length as key')
#    2539                 for k1, k2 in zip(key, value.columns):
# -> 2540                     self[k1] = value[k2]
#    2541             else:
#    2542                 indexer = self.loc._convert_to_indexer(key, axis=1)
#
# /Users/irarickman/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __setitem__(self, key, value)
#    2517         else:
#    2518             # set column
# -> 2519             self._set_item(key, value)
#    2520
#    2521     def _setitem_slice(self, key, value):
#
# /Users/irarickman/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _set_item(self, key, value)
#    2582         """
#    2583
# -> 2584         self._ensure_valid_index(value)
#    2585         value = self._sanitize_column(key, value)
#    2586         NDFrame._set_item(self, key, value)
#
# /Users/irarickman/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _ensure_valid_index(self, value)
#    2564                 value = Series(value)
#    2565             except:
# -> 2566                 raise ValueError('Cannot set a frame with no defined index '
#    2567                                  'and a value that cannot be converted to a '
#    2568                                  'Series')
#
# ValueError: Cannot set a frame with no defined index and a value that cannot be converted to a Series

# %%
data.shape
# Out:
# (3815, 90)

# %%
data[data.events.notnull()].shape
# Out:
# (976, 90)
