# %%
import pandas as pd
from pybaseball import statcast
pd.options.display.max_rows=100
pd.options.display.max_columns=100

# %%
df=pd.read_csv("savant_data(30).csv")
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-3-d73d090c93d4> in <module>()
# ----> 1 df=pd.read_csv("savant_data(30).csv")
#
# /Users/irarickman/anaconda2/lib/python2.7/site-packages/pandas/io/parsers.pyc in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     707                     skip_blank_lines=skip_blank_lines)
#     708
# --> 709         return _read(filepath_or_buffer, kwds)
#     710
#     711     parser_f.__name__ = name
#
# /Users/irarickman/anaconda2/lib/python2.7/site-packages/pandas/io/parsers.pyc in _read(filepath_or_buffer, kwds)
#     447
#     448     # Create the parser.
# --> 449     parser = TextFileReader(filepath_or_buffer, **kwds)
#     450
#     451     if chunksize or iterator:
#
# /Users/irarickman/anaconda2/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, f, engine, **kwds)
#     816             self.options['has_index_names'] = kwds['has_index_names']
#     817
# --> 818         self._make_engine(self.engine)
#     819
#     820     def close(self):
#
# /Users/irarickman/anaconda2/lib/python2.7/site-packages/pandas/io/parsers.pyc in _make_engine(self, engine)
#    1047     def _make_engine(self, engine='c'):
#    1048         if engine == 'c':
# -> 1049             self._engine = CParserWrapper(self.f, **self.options)
#    1050         else:
#    1051             if engine == 'python':
#
# /Users/irarickman/anaconda2/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, src, **kwds)
#    1693         kwds['allow_leading_cols'] = self.index_col is not False
#    1694
# -> 1695         self._reader = parsers.TextReader(src, **kwds)
#    1696
#    1697         # XXX
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# IOError: File savant_data(30).csv does not exist

# %%
df.shape
# Out:
# (40000, 89)

# %%
df.head()
# Out:
#   pitch_type game_date  release_speed  release_pos_x  release_pos_z  \
# 0         FF   6/20/18           95.5        -1.7171         6.2791
# 1         SL   6/20/18           84.2        -2.4159         5.9941
# 2         FC   6/20/18           88.5        -2.1485         6.0516
# 3         FC   6/20/18           87.5        -1.7531         6.1742
# 4         SL   6/20/18           83.7        -2.4143         5.9742
#
#         player_name  batter  pitcher     events           description  \
# 0  Asdrubal Cabrera  452678   451584  field_out         hit_into_play
# 1       Eric Hosmer  543333   572998  strikeout       swinging_strike
# 2     Brandon Nimmo  607043   451584  field_out         hit_into_play
# 3      Amed Rosario  642708   451584     single  hit_into_play_no_out
# 4  Travis Jankowski  608671   572998     double   hit_into_play_score
#
#            ...           home_score  away_score  bat_score  fld_score  \
# 0          ...                   10           8          8         10
# 1          ...                    4          12          4         12
# 2          ...                   10           8          8         10
# 3          ...                   10           8          8         10
# 4          ...                    2          12          2         12
#
#    post_away_score post_home_score post_bat_score post_fld_score  \
# 0                8              10              8             10
# 1               12               4              4             12
# 2                8              10              8             10
# 3                8              10              8             10
# 4               12               2              2             12
#
#   if_fielding_alignment of_fielding_alignment
# 0             Strategic             Strategic
# 1              Standard              Standard
# 2              Standard             Strategic
# 3              Standard              Standard
# 4              Standard              Standard
#
# [5 rows x 89 columns]

# %%
df.player_name.nunique()
# Out:
# 671

# %%
df.events.value_counts()
# Out:
# field_out                    17841
# strikeout                     9850
# single                        6260
# double                        1985
# home_run                      1363
# force_out                      878
# grounded_into_double_play      874
# sac_fly                        269
# triple                         217
# sac_bunt                       197
# double_play                    116
# fielders_choice_out             81
# strikeout_double_play           45
# fielders_choice                 21
# sac_fly_double_play              2
# sac_bunt_double_play             1
# Name: events, dtype: int64

# %%
df.events.isnull().sum()
# Out:
# 0

# %%
df['hit']=df.events.apply(lambda x: 1 if x in ["single",'double','home_run','triple'] else 0)
df['ab']=df.events.apply(lambda x: 0 if x in ["sac_fly",'sac_bunt','sac_fly_double_play','sac_bunt_double_play'] else 1)

# %%
df['date']=pd.to_datetime(df['game_date'],infer_datetime_format=True)
sorted(df.date.unique())
# Out:
# [numpy.datetime64('2018-05-07T00:00:00.000000000'),
#  numpy.datetime64('2018-05-08T00:00:00.000000000'),
#  numpy.datetime64('2018-05-09T00:00:00.000000000'),
#  numpy.datetime64('2018-05-10T00:00:00.000000000'),
#  numpy.datetime64('2018-05-11T00:00:00.000000000'),
#  numpy.datetime64('2018-05-12T00:00:00.000000000'),
#  numpy.datetime64('2018-05-13T00:00:00.000000000'),
#  numpy.datetime64('2018-05-14T00:00:00.000000000'),
#  numpy.datetime64('2018-05-15T00:00:00.000000000'),
#  numpy.datetime64('2018-05-16T00:00:00.000000000'),
#  numpy.datetime64('2018-05-17T00:00:00.000000000'),
#  numpy.datetime64('2018-05-18T00:00:00.000000000'),
#  numpy.datetime64('2018-05-19T00:00:00.000000000'),
#  numpy.datetime64('2018-05-20T00:00:00.000000000'),
#  numpy.datetime64('2018-05-21T00:00:00.000000000'),
#  numpy.datetime64('2018-05-22T00:00:00.000000000'),
#  numpy.datetime64('2018-05-23T00:00:00.000000000'),
#  numpy.datetime64('2018-05-24T00:00:00.000000000'),
#  numpy.datetime64('2018-05-25T00:00:00.000000000'),
#  numpy.datetime64('2018-05-26T00:00:00.000000000'),
#  numpy.datetime64('2018-05-27T00:00:00.000000000'),
#  numpy.datetime64('2018-05-28T00:00:00.000000000'),
#  numpy.datetime64('2018-05-29T00:00:00.000000000'),
#  numpy.datetime64('2018-05-30T00:00:00.000000000'),
#  numpy.datetime64('2018-05-31T00:00:00.000000000'),
#  numpy.datetime64('2018-06-01T00:00:00.000000000'),
#  numpy.datetime64('2018-06-02T00:00:00.000000000'),
#  numpy.datetime64('2018-06-03T00:00:00.000000000'),
#  numpy.datetime64('2018-06-04T00:00:00.000000000'),
#  numpy.datetime64('2018-06-05T00:00:00.000000000'),
#  numpy.datetime64('2018-06-06T00:00:00.000000000'),
#  numpy.datetime64('2018-06-07T00:00:00.000000000'),
#  numpy.datetime64('2018-06-08T00:00:00.000000000'),
#  numpy.datetime64('2018-06-09T00:00:00.000000000'),
#  numpy.datetime64('2018-06-10T00:00:00.000000000'),
#  numpy.datetime64('2018-06-11T00:00:00.000000000'),
#  numpy.datetime64('2018-06-12T00:00:00.000000000'),
#  numpy.datetime64('2018-06-13T00:00:00.000000000'),
#  numpy.datetime64('2018-06-14T00:00:00.000000000'),
#  numpy.datetime64('2018-06-15T00:00:00.000000000'),
#  numpy.datetime64('2018-06-16T00:00:00.000000000'),
#  numpy.datetime64('2018-06-17T00:00:00.000000000'),
#  numpy.datetime64('2018-06-18T00:00:00.000000000'),
#  numpy.datetime64('2018-06-19T00:00:00.000000000'),
#  numpy.datetime64('2018-06-20T00:00:00.000000000')]

# %%
df['htd']=df.sort_values(['date','inning'],ascending=True).groupby(['player_name']).hit.cumsum()
df['abtd']=df.sort_values(['date','inning'],ascending=True).groupby(['player_name']).ab.cumsum()
df['avg']=df.htd/df.abtd

# %%
df[['player_name','date','inning','hit','ab','htd','abtd','avg']].sort_values(['player_name','date','inning'],ascending=True).head(100)
# Out:
#          player_name       date  inning  hit  ab  htd  abtd       avg
# 38668     A.J. Ellis 2018-05-09       2    1   1    1     1  1.000000
# 38458     A.J. Ellis 2018-05-09       4    1   1    2     2  1.000000
# 38259     A.J. Ellis 2018-05-09       6    0   1    2     3  0.666667
# 37533  Aaron Altherr 2018-05-10       5    0   1    2     9  0.222222
# 37156  Aaron Altherr 2018-05-11       1    0   1    2    10  0.200000
# 36933  Aaron Altherr 2018-05-11       3    0   1    2    11  0.181818
# 36527  Aaron Altherr 2018-05-11       7    0   1    2    12  0.166667
# 34776  Aaron Altherr 2018-05-13       2    0   1    2    13  0.153846
# 34555  Aaron Altherr 2018-05-13       5    0   1    2    14  0.142857
# 34288  Aaron Altherr 2018-05-13       7    0   1    2    15  0.133333
# 31823  Aaron Altherr 2018-05-16       8    0   1    2    16  0.125000
# 31635  Aaron Altherr 2018-05-17       1    0   1    2    17  0.117647
# 31488  Aaron Altherr 2018-05-17       4    0   1    2    18  0.111111
# 31354  Aaron Altherr 2018-05-17       6    0   1    2    19  0.105263
# 31210  Aaron Altherr 2018-05-17       8    1   1    3    20  0.150000
# 31104  Aaron Altherr 2018-05-17       9    0   1    3    21  0.142857
# 29097  Aaron Altherr 2018-05-19       8    0   1    3    22  0.136364
# 28780  Aaron Altherr 2018-05-20       2    0   1    3    23  0.130435
# 28456  Aaron Altherr 2018-05-20       5    0   1    3    24  0.125000
# 28140  Aaron Altherr 2018-05-20       8    1   1    4    25  0.160000

# %%
df.to_csv("all_abs_edit.csv")

# %%
## statcast test
# %timeit
data=statcast()
# Out:
# Warning: no date range supplied. Returning yesterday's Statcast data. For a different date range, try get_statcast(start_dt, end_dt).
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-63bb5460ed4c> in <module>()
#       1 ## statcast test
#       2 get_ipython().magic(u'timeit')
# ----> 3 data=statcast()
#
# /Users/irarickman/anaconda2/lib/python2.7/site-packages/pybaseball/statcast.pyc in statcast(start_dt, end_dt, team, verbose)
#     201             data = large_request(start_dt,end_dt,d1,d2,step=small_query_threshold,verbose=verbose)
#     202
# --> 203         data = postprocessing(data, team)
#     204         return data
#     205
#
# /Users/irarickman/anaconda2/lib/python2.7/site-packages/pybaseball/statcast.pyc in postprocessing(data, team)
#     153                     'fld_score','post_away_score','post_home_score','post_bat_score','post_fld_score']
#     154
# --> 155     data[numeric_cols] = data[numeric_cols].astype(float)
#     156
#     157     # convert date col to datetime data type and sort so that this returns in an order that makes sense (by date and game)
#
# /Users/irarickman/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __setitem__(self, key, value)
#    2512
#    2513         if isinstance(key, (Series, np.ndarray, list, Index)):
# -> 2514             self._setitem_array(key, value)
#    2515         elif isinstance(key, DataFrame):
#    2516             self._setitem_frame(key, value)
#
# /Users/irarickman/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _setitem_array(self, key, value)
#    2538                     raise ValueError('Columns must be same length as key')
#    2539                 for k1, k2 in zip(key, value.columns):
# -> 2540                     self[k1] = value[k2]
#    2541             else:
#    2542                 indexer = self.loc._convert_to_indexer(key, axis=1)
#
# /Users/irarickman/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __setitem__(self, key, value)
#    2517         else:
#    2518             # set column
# -> 2519             self._set_item(key, value)
#    2520
#    2521     def _setitem_slice(self, key, value):
#
# /Users/irarickman/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _set_item(self, key, value)
#    2582         """
#    2583
# -> 2584         self._ensure_valid_index(value)
#    2585         value = self._sanitize_column(key, value)
#    2586         NDFrame._set_item(self, key, value)
#
# /Users/irarickman/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _ensure_valid_index(self, value)
#    2564                 value = Series(value)
#    2565             except:
# -> 2566                 raise ValueError('Cannot set a frame with no defined index '
#    2567                                  'and a value that cannot be converted to a '
#    2568                                  'Series')
#
# ValueError: Cannot set a frame with no defined index and a value that cannot be converted to a Series

# %%
data.shape
# Out:
# (3815, 90)

# %%
data[data.events.notnull()].shape
# Out:
# (976, 90)
